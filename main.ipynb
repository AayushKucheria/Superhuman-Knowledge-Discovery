# %%
import torch

# %%
model = torch.load("t3-512x15x16h-distill-swa-2767500.pth", weights_only=False)
print(model)
# Out:
# GraphModule(
#   (attn_body/transpose): OnnxTranspose()
#   (initializers): Module()
#   (attn_body/reshape): OnnxReshape()
#   (attn_body/embedding/slice): OnnxSlice()
#   (attn_body/embedding/reshape): OnnxReshape()
#   (attn_body/embedding/preprocess/matmul): OnnxMatMul()
#   (attn_body/embedding/preprocess/add): OnnxBinaryMathOperation()
#   (attn_body/embedding/preprocess/reshape): OnnxReshape()
#   (attn_body/embedding/concat): OnnxConcat()
#   (attn_body/embedding/out/reshape): OnnxReshape()
#   (attn_body/matmul): OnnxMatMul()
#   (attn_body/add): OnnxBinaryMathOperation()
#   (attn_body/mish/softplus): Softplus(beta=1.0, threshold=20.0)
#   (attn_body/mish/tanh): OnnxFunction()
#   (attn_body/mish): OnnxBinaryMathOperation()
#   (attn_body/ln): LayerNorm((512,), eps=0.0010000000474974513, elementwise_affine=True)
#   (attn_body/ma_gating/rehape1): OnnxReshape()
#   (ip_mul_gate): OnnxBinaryMathOperation()
#   (ip_add_gate): OnnxBinaryMathOperation()
# ...

# %%
from torchinfo import summary

summary(model, input_size=(1, 112, 8, 8))
# Out:
# ...
# Layer (type:depth-idx)                   Output Shape              Param #
# ...
# GraphModule                              [1, 1858]                 --
# ├─OnnxTranspose: 1-1                     [1, 8, 8, 112]            --
# ├─OnnxReshape: 1-2                       [1, 64, 112]              --
# ├─OnnxSlice: 1-3                         [1, 64, 12]               --
# ├─OnnxReshape: 1-4                       [1, 768]                  --
# ├─OnnxMatMul: 1-5                        [1, 32768]                --
# ├─OnnxBinaryMathOperation: 1-6           [1, 32768]                --
# ├─OnnxReshape: 1-7                       [1, 64, 512]              --
# ├─OnnxConcat: 1-8                        [1, 64, 624]              --
# ├─OnnxReshape: 1-9                       [64, 624]                 --
# ├─OnnxMatMul: 1-10                       [64, 512]                 --
# ├─OnnxBinaryMathOperation: 1-11          [64, 512]                 --
# ...
